# %%
import pandas as pd

# %%
loan_df = pd.read_csv('data/loan.csv')
loan_df
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 0    LP1003              Y                    N              4583
# 1    LP1005              Y                    Y              3000
# 2    LP1006              Y                    N              2583
# 3    LP1008              N                    N              6000
# 4    LP1011              Y                    Y              5417
# ..      ...            ...                  ...               ...
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
# 599  LP2990              N                    Y              4583
#
#      loan_amount property_area loan_status
# 0          128.4         Rural           N
# 1           66.0          City           Y
# 2          120.5          City           Y
# 3          141.4          City           Y
# 4          267.4          City           Y
# ..           ...           ...         ...
# 595        108.6         Rural           Y
# 596         40.7         Rural           Y
# 597        253.4          City           Y
# 598        187.6          City           Y
# 599        133.2        Suburb           N
#
# [600 rows x 7 columns]

# %%
condition1 = loan_df['married_or_not'] == 'Y'

# %%
loan_df['applicant_income'].mean()
# Out:
# 5412.161666666667

# %%
loan_df = loan_df.set_index('loan_id')

# %%
loan_df.columns
# Out:
# Index(['married_or_not', 'self_employed_or_not', 'applicant_income',
#        'loan_amount', 'property_area', 'loan_status'],
#       dtype='object')

# %%
loan_df.columns = ['married', 'self_employed', 'income', 'amount', 'property_area', 'loan_status']
loan_df
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1003        Y             N    4583   128.4         Rural           N
# LP1005        Y             Y    3000    66.0          City           Y
# LP1006        Y             N    2583   120.5          City           Y
# LP1008        N             N    6000   141.4          City           Y
# LP1011        Y             Y    5417   267.4          City           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2974        Y             N    3232   108.6         Rural           Y
# LP2979        Y             N    4106    40.7         Rural           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
# LP2990        N             Y    4583   133.2        Suburb           N
#
# [600 rows x 6 columns]

# %%
condition1 = loan_df['married'] == 'Y'

# %%
loan_df['income'].mean()
# Out:
# 5412.161666666667

# %%
condition2 = loan_df['income'] > loan_df['income'].mean()

# %%
loan_df[condition1 & condition2]
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1011        Y             Y    5417   267.4          City           Y
# LP1020        Y             N   12841   349.3        Suburb           N
# LP1043        Y             N    7660   104.1          City           N
# LP1046        Y             N    5955   315.5          City           Y
# LP1066        Y             Y    9560   191.1        Suburb           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2948        Y             N    5780   192.9          City           Y
# LP2953        Y             N    5703   128.5          City           Y
# LP2959        Y             N   12000   497.0        Suburb           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
#
# [120 rows x 6 columns]

# %%
loan_df[condition1 | condition2]
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1003        Y             N    4583   128.4         Rural           N
# LP1005        Y             Y    3000    66.0          City           Y
# LP1006        Y             N    2583   120.5          City           Y
# LP1008        N             N    6000   141.4          City           Y
# LP1011        Y             Y    5417   267.4          City           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2964        Y             N    3987   157.3         Rural           Y
# LP2974        Y             N    3232   108.6         Rural           Y
# LP2979        Y             N    4106    40.7         Rural           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
#
# [442 rows x 6 columns]

# %%
loan_df[(loan_df['married'] == 'Y') | (loan_df['income'] > loan_df['income'].mean())]
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1003        Y             N    4583   128.4         Rural           N
# LP1005        Y             Y    3000    66.0          City           Y
# LP1006        Y             N    2583   120.5          City           Y
# LP1008        N             N    6000   141.4          City           Y
# LP1011        Y             Y    5417   267.4          City           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2964        Y             N    3987   157.3         Rural           Y
# LP2974        Y             N    3232   108.6         Rural           Y
# LP2979        Y             N    4106    40.7         Rural           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
#
# [442 rows x 6 columns]

# %%
# 결혼을 했거나, 수입이 전체 평균보다 크고, 부동산이 도시에 있지 않다.

# %%
condition3 = loan_df['property_area'] == 'City'

# %%
loan_df[condition1 | condition2 & ~condition3]
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1003        Y             N    4583   128.4         Rural           N
# LP1005        Y             Y    3000    66.0          City           Y
# LP1006        Y             N    2583   120.5          City           Y
# LP1011        Y             Y    5417   267.4          City           Y
# LP1013        Y             N    2333    95.3          City           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2964        Y             N    3987   157.3         Rural           Y
# LP2974        Y             N    3232   108.6         Rural           Y
# LP2979        Y             N    4106    40.7         Rural           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
#
# [426 rows x 6 columns]

# %%
# 데이터 삭제하기

# %%
loan_df
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1003        Y             N    4583   128.4         Rural           N
# LP1005        Y             Y    3000    66.0          City           Y
# LP1006        Y             N    2583   120.5          City           Y
# LP1008        N             N    6000   141.4          City           Y
# LP1011        Y             Y    5417   267.4          City           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2974        Y             N    3232   108.6         Rural           Y
# LP2979        Y             N    4106    40.7         Rural           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
# LP2990        N             Y    4583   133.2        Suburb           N
#
# [600 rows x 6 columns]

# %%
loan_df = loan_df.drop('LP1006')

# %%
loan_df
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1003        Y             N    4583   128.4         Rural           N
# LP1005        Y             Y    3000    66.0          City           Y
# LP1008        N             N    6000   141.4          City           Y
# LP1011        Y             Y    5417   267.4          City           Y
# LP1013        Y             N    2333    95.3          City           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2974        Y             N    3232   108.6         Rural           Y
# LP2979        Y             N    4106    40.7         Rural           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
# LP2990        N             Y    4583   133.2        Suburb           N
#
# [599 rows x 6 columns]

# %%
# 데이터 내보내기

# %%
loan_df.to_csv('data/loan1.csv')

# %%
loan1_df = pd.read_csv('data/loan1.csv')

# %%
loan1_df
# Out:
#     loan_id married self_employed  income  amount property_area loan_status
# 0    LP1003       Y             N    4583   128.4         Rural           N
# 1    LP1005       Y             Y    3000    66.0          City           Y
# 2    LP1008       N             N    6000   141.4          City           Y
# 3    LP1011       Y             Y    5417   267.4          City           Y
# 4    LP1013       Y             N    2333    95.3          City           Y
# ..      ...     ...           ...     ...     ...           ...         ...
# 594  LP2974       Y             N    3232   108.6         Rural           Y
# 595  LP2979       Y             N    4106    40.7         Rural           Y
# 596  LP2983       Y             N    8072   253.4          City           Y
# 597  LP2984       Y             N    7583   187.6          City           Y
# 598  LP2990       N             Y    4583   133.2        Suburb           N
#
# [599 rows x 7 columns]

# %%
loan1_df.to_csv('data/loan2.csv')

# %%
loan2_df = pd.read_csv('data/loan2.csv')

# %%
loan2_df
# Out:
#      Unnamed: 0 loan_id married self_employed  income  amount property_area  \
# 0             0  LP1003       Y             N    4583   128.4         Rural
# 1             1  LP1005       Y             Y    3000    66.0          City
# 2             2  LP1008       N             N    6000   141.4          City
# 3             3  LP1011       Y             Y    5417   267.4          City
# 4             4  LP1013       Y             N    2333    95.3          City
# ..          ...     ...     ...           ...     ...     ...           ...
# 594         594  LP2974       Y             N    3232   108.6         Rural
# 595         595  LP2979       Y             N    4106    40.7         Rural
# 596         596  LP2983       Y             N    8072   253.4          City
# 597         597  LP2984       Y             N    7583   187.6          City
# 598         598  LP2990       N             Y    4583   133.2        Suburb
#
#     loan_status
# 0             N
# 1             Y
# 2             Y
# 3             Y
# 4             Y
# ..          ...
# 594           Y
# 595           Y
# 596           Y
# 597           Y
# 598           N
#
# [599 rows x 8 columns]

# %%
loan1_df.to_csv('data/loan3.csv', index=False)

# %%
loan3_df = pd.read_csv('data/loan3.csv')

# %%
loan3_df
# Out:
#     loan_id married self_employed  income  amount property_area loan_status
# 0    LP1003       Y             N    4583   128.4         Rural           N
# 1    LP1005       Y             Y    3000    66.0          City           Y
# 2    LP1008       N             N    6000   141.4          City           Y
# 3    LP1011       Y             Y    5417   267.4          City           Y
# 4    LP1013       Y             N    2333    95.3          City           Y
# ..      ...     ...           ...     ...     ...           ...         ...
# 594  LP2974       Y             N    3232   108.6         Rural           Y
# 595  LP2979       Y             N    4106    40.7         Rural           Y
# 596  LP2983       Y             N    8072   253.4          City           Y
# 597  LP2984       Y             N    7583   187.6          City           Y
# 598  LP2990       N             Y    4583   133.2        Suburb           N
#
# [599 rows x 7 columns]

# %%
loan1_df.to_excel('data/loan1.xlsx')
