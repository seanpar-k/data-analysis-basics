# %%
import pandas as pd

# %%
loan_df = pd.read_csv('data/loan.csv')
loan_df
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 0    LP1003              Y                    N              4583
# 1    LP1005              Y                    Y              3000
# 2    LP1006              Y                    N              2583
# 3    LP1008              N                    N              6000
# 4    LP1011              Y                    Y              5417
# ..      ...            ...                  ...               ...
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
# 599  LP2990              N                    Y              4583
#
#      loan_amount property_area loan_status
# 0          128.4         Rural           N
# 1           66.0          City           Y
# 2          120.5          City           Y
# 3          141.4          City           Y
# 4          267.4          City           Y
# ..           ...           ...         ...
# 595        108.6         Rural           Y
# 596         40.7         Rural           Y
# 597        253.4          City           Y
# 598        187.6          City           Y
# 599        133.2        Suburb           N
#
# [600 rows x 7 columns]

# %%
loan_df = loan_df.set_index('loan_id')

# %%
loan_df.columns = ['married', 'self_employed', 'income', 'amount', 'property_area', 'loan_status']

# %%
loan_df
# Out:
#         married self_employed  income  amount property_area loan_status
# loan_id
# LP1003        Y             N    4583   128.4         Rural           N
# LP1005        Y             Y    3000    66.0          City           Y
# LP1006        Y             N    2583   120.5          City           Y
# LP1008        N             N    6000   141.4          City           Y
# LP1011        Y             Y    5417   267.4          City           Y
# ...         ...           ...     ...     ...           ...         ...
# LP2974        Y             N    3232   108.6         Rural           Y
# LP2979        Y             N    4106    40.7         Rural           Y
# LP2983        Y             N    8072   253.4          City           Y
# LP2984        Y             N    7583   187.6          City           Y
# LP2990        N             Y    4583   133.2        Suburb           N
#
# [600 rows x 6 columns]

# %%
loan_df['amount']
# Out:
# loan_id
# LP1003    128.4
# LP1005     66.0
# LP1006    120.5
# LP1008    141.4
# LP1011    267.4
#           ...
# LP2974    108.6
# LP2979     40.7
# LP2983    253.4
# LP2984    187.6
# LP2990    133.2
# Name: amount, Length: 600, dtype: float64

# %%
loan_df['amount'].dtype
# Out:
# dtype('float64')

# %%
loan_df['amount'].describe()
# Out:
# count    589.000000
# mean     146.971307
# std       85.756442
# min        9.200000
# 25%      100.700000
# 50%      128.000000
# 75%      168.300000
# max      700.300000
# Name: amount, dtype: float64

# %%
loan_df['self_employed'].dtype
# Out:
# dtype('O')

# %%
loan_df['self_employed'].describe()
# Out:
# count     568
# unique      2
# top         N
# freq      488
# Name: self_employed, dtype: object

# %%
loan_df['self_employed'].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %%
loan_df['self_employed'].value_counts()
# Out:
# self_employed
# N    488
# Y     80
# Name: count, dtype: int64

# %%
loan_df['self_employed'].value_counts(dropna=False)
# Out:
# self_employed
# N      488
# Y       80
# NaN     32
# Name: count, dtype: int64

# %%
loan_df['self_employed'].value_counts(dropna=False, normalize=True)
# Out:
# self_employed
# N      0.813333
# Y      0.133333
# NaN    0.053333
# Name: proportion, dtype: float64

# %%
loan_df[['amount', 'income']]
# Out:
#          amount  income
# loan_id
# LP1003    128.4    4583
# LP1005     66.0    3000
# LP1006    120.5    2583
# LP1008    141.4    6000
# LP1011    267.4    5417
# ...         ...     ...
# LP2974    108.6    3232
# LP2979     40.7    4106
# LP2983    253.4    8072
# LP2984    187.6    7583
# LP2990    133.2    4583
#
# [600 rows x 2 columns]

# %%
loan_df[['amount']]
# Out:
#          amount
# loan_id
# LP1003    128.4
# LP1005     66.0
# LP1006    120.5
# LP1008    141.4
# LP1011    267.4
# ...         ...
# LP2974    108.6
# LP2979     40.7
# LP2983    253.4
# LP2984    187.6
# LP2990    133.2
#
# [600 rows x 1 columns]

# %%
loan_df['amount']
# Out:
# loan_id
# LP1003    128.4
# LP1005     66.0
# LP1006    120.5
# LP1008    141.4
# LP1011    267.4
#           ...
# LP2974    108.6
# LP2979     40.7
# LP2983    253.4
# LP2984    187.6
# LP2990    133.2
# Name: amount, Length: 600, dtype: float64

# %%
loan_df['amount'].unique()
# Out:
# array([128.4,  66. , 120.5, 141.4, 267.4,  95.3, 158.2, 168.6, 349.3,
#         70.3, 109.6, 200.5, 114.1,  17.5, 125.2, 100.8,  76.9, 133.5,
#        115.8, 104.1, 315.5, 116.1, 112.4, 151.1, 191.1, 122.6, 110.2,
#         35.1, 120.2, 201.3,  74.5, 106.2, 114.6, 320.5, 100.5, 144.4,
#        184.8, 110.6,  80.2,  47.7,  76. , 134.5,  96.9,  88.3,  44.6,
#        120.4, 144.8, 121. , 112.5, 134.1, 286.4,  97.9,  96.4, 135. ,
#        180.2, 144.1, 100. , 165.8,   nan, 116.8, 258.2, 126.3, 312.5,
#        125.4, 136. , 173. ,  97.4,  81.5, 187.3, 113.4, 176.8, 110.7,
#        180.4, 130. , 111.8, 167.3, 265.6,  50. , 136.7,  99.4, 104.5,
#        210.4, 175.4, 131.6, 189. ,  81.1, 122.3,  25. , 137.7,  50.2,
#        115.4, 133.7, 151.2, 100.9, 225.8, 120.1, 216.9,  94.7, 136.8,
#        139.5, 152.2, 118.9, 185.6, 154.3,  85.3, 175.9, 259.4, 180.5,
#        137.8,  81.6, 194.2,  93.6, 370.5, 160.5, 182.7, 650.2,  74.2,
#         70.1,  25.3, 102. , 290.6,  84.3,  88.2, 242.1, 129.3, 185.2,
#        168.3, 175.5, 122.5, 187.8, 101. ,  70. ,  30.2, 225.6, 244.7,
#        113.7,  50.8, 600. , 160.2, 187.7, 255. ,  98.4, 275.6, 121.1,
#        158.1,  75. , 182.4, 112.7, 129.2,  63.9, 200.4,  95.6, 700.3,
#        188. ,  87.4, 116.2, 101.4, 495.4, 116.5, 102.5, 180. ,  67.2,
#         73.5, 260.7, 108.8, 120.8,  66.5,  59. , 188.5,  48.7, 164.9,
#        160.4,  76.8, 170.7, 187. , 120. , 113.9,  83.1,  90.7, 166.3,
#        135.4, 124.9, 120.6,  80.9,  55.7,  59.5, 127.5, 214.2, 128. ,
